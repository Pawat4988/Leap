# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("numPartitionCQM.xlsx")
df
# Out:
#      Unnamed: 0  Problem No.  \
# 0             0            0
# 1             1            0
# 2             2            0
# 3             3            0
# 4             4            0
# ..          ...          ...
# 786         786           14
# 787         787           14
# 788         788           14
# 789         789           14
# 790         790           14
#
#                                                 Answer  QPU Access Time  \
# 0    {0: 0.0, 1: 1.0, 2: 1.0, 3: 0.0, 4: 1.0, 5: 0....            15165
# 1    {0: 1.0, 1: 1.0, 2: 1.0, 3: 0.0, 4: 0.0, 5: 1....            15165
# 2    {0: 0.0, 1: 1.0, 2: 1.0, 3: 0.0, 4: 1.0, 5: 0....            15165
# 3    {0: 0.0, 1: 1.0, 2: 1.0, 3: 0.0, 4: 1.0, 5: 0....            15165
# 4    {0: 1.0, 1: 1.0, 2: 1.0, 3: 0.0, 4: 0.0, 5: 1....            15165
# ..                                                 ...              ...
# 786  {0: 0.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 0.0, 5: 0....            15149
# ...

# %%
answers = df.loc[:,"Answer"].to_list()
print(answers)

# %%
df['relative error'] = 

r = abs(sbest - s)/abs(sBest-sWorst)
